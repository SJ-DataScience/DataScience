# %% [markdown]
# # Applied Data Science - Capstone Project
# ## April 2020
#
# ## Assignment Ask
#
#
# #### Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.
#
#
# ## Decision making to open restaurants in new locations

# %% [markdown]
# ### Import packages

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

# %%
import json

from geopy.geocoders import Nominatim 

import requests
from pandas.io.json import json_normalize

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
! pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 14.2MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup


import matplotlib.pyplot as plt
import pylab as pl

from sklearn import linear_model
from sklearn.metrics import jaccard_similarity_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import log_loss
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
import itertools


print('Libraries import done')
# Out:
# Libraries import done

# %% [markdown]
# ## -------------------------------------------------------------DATA------------------------------------------------------------------------------
# ### Data Scraping and Cleaning

# %%
address1 = 'Atlanta, Georgia'

geolocator = Nominatim()
location1 = geolocator.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address1, latitude1, longitude1))


address2 = 'Miami, Florida'

geolocator = Nominatim()
location2 = geolocator.geocode(address2)
latitude2 = location2.latitude
longitude2 = location2.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address2, latitude2, longitude2))

address3 = 'Tampa, Florida'

geolocator = Nominatim()
location3 = geolocator.geocode(address3)
latitude3 = location3.latitude
longitude3 = location3.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address3, latitude3, longitude3))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Atlanta, Georgia are 33.7490987, -84.3901849.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:12: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Miami, Florida are 25.7742658, -80.1936589.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:20: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Tampa, Florida are 27.9477595, -82.458444.

# %% [markdown]
# ### Establish Connection with FourSquare

# %%
CLIENT_ID = 'HX1GE2552CECMWAE5EKMLITXXGI54P2ORGDIOIIYNTFYPWVK' # Sheetal Foursquare ID
CLIENT_SECRET = 'GLC0ASBQIIS52GXAX4EVALT3SXBPBED3AQLMBGGW5ERNBK1M' # Sheetal Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)


LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius

# create URLs
url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude1, 
    longitude1, 
    radius, 
    LIMIT)


# create URLs
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude2, 
    longitude2, 
    radius, 
    LIMIT)


# create URLs
url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude3, 
    longitude3, 
    radius, 
    LIMIT)

print(url1, url2, url3)
# Out:
# My credentails:
# CLIENT_ID: HX1GE2552CECMWAE5EKMLITXXGI54P2ORGDIOIIYNTFYPWVK
# CLIENT_SECRET:GLC0ASBQIIS52GXAX4EVALT3SXBPBED3AQLMBGGW5ERNBK1M
# https://api.foursquare.com/v2/venues/explore?&client_id=HX1GE2552CECMWAE5EKMLITXXGI54P2ORGDIOIIYNTFYPWVK&client_secret=GLC0ASBQIIS52GXAX4EVALT3SXBPBED3AQLMBGGW5ERNBK1M&v=20180605&ll=33.7490987,-84.3901849&radius=1000&limit=100 https://api.foursquare.com/v2/venues/explore?&client_id=HX1GE2552CECMWAE5EKMLITXXGI54P2ORGDIOIIYNTFYPWVK&client_secret=GLC0ASBQIIS52GXAX4EVALT3SXBPBED3AQLMBGGW5ERNBK1M&v=20180605&ll=25.7742658,-80.1936589&radius=1000&limit=100 https://api.foursquare.com/v2/venues/explore?&client_id=HX1GE2552CECMWAE5EKMLITXXGI54P2ORGDIOIIYNTFYPWVK&client_secret=GLC0ASBQIIS52GXAX4EVALT3SXBPBED3AQLMBGGW5ERNBK1M&v=20180605&ll=27.9477595,-82.458444&radius=1000&limit=100

# %% [markdown]
# ## Data Scraping

# %%
# scrape the data from the generated URLs

results1 = requests.get(url1).json()
results1

results2 = requests.get(url2).json()
results2

results3 = requests.get(url3).json()
results3

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    

### first city ###    
    
venues1 = results1['response']['groups'][0]['items']
nearby_venues1 = json_normalize(venues1) # flatten JSON

# filter columns
filtered_columns1 = ['venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues1 =nearby_venues1.loc[:, filtered_columns1]

# filter the category for each row
nearby_venues1['venue.categories'] = nearby_venues1.apply(get_category_type, axis=1)

# clean columns
nearby_venues1.columns = [col.split(".")[-1] for col in nearby_venues1.columns]


### second city ###

venues2 = results2['response']['groups'][0]['items']
nearby_venues2 = json_normalize(venues2) # flatten JSON

# filter columns
filtered_columns2 = ['venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues2 =nearby_venues2.loc[:, filtered_columns2]

# filter the category for each row
nearby_venues2['venue.categories'] = nearby_venues2.apply(get_category_type, axis=1)

# clean columns
nearby_venues2.columns = [col.split(".")[-1] for col in nearby_venues2.columns]


### third city ###

venues3 = results3['response']['groups'][0]['items']
nearby_venues3 = json_normalize(venues3) # flatten JSON

# filter columns
filtered_columns3 = ['venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues3 =nearby_venues3.loc[:, filtered_columns3]

# filter the category for each row
nearby_venues3['venue.categories'] = nearby_venues3.apply(get_category_type, axis=1)

# clean columns
nearby_venues3.columns = [col.split(".")[-1] for col in nearby_venues3.columns]





print('{} venues were returned by Foursquare.'.format(nearby_venues1.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues2.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues3.shape[0]))
# Out:
# 67 venues were returned by Foursquare.
# 100 venues were returned by Foursquare.
# 93 venues were returned by Foursquare.

# %%
# add locations data to the data sets of each city

nearby_venues1['city'] = 'Atlanta'
nearby_venues2['city'] = 'Miami'
nearby_venues3['city'] = 'Tampa'

# %%
# combine the three cities into one data set

nearby_venues = nearby_venues1.copy()
nearby_venues = nearby_venues.append(nearby_venues2)
nearby_venues = nearby_venues.append(nearby_venues3)

# %% [markdown]
# ### Data Cleaning to remove non restaurant related DATA

# %%
# check list and manually remove all non-restaurant data

nearby_venues['categories'].unique()

removal_list = ['Concert Hall', 'Opera House', 'Dance Studio',
                'Performing Arts Venue', 'Art Museum', 'Park',
                'Massage Studio', 'Music Venue', 'Bookstore', 'Clothing Store',
                'Boutique', 'Furniture/Home Store', 'Jazz Club',
                'Theater', 'Optical Shop', "Men's Store", 'Rock Club',
                'Gym / Fitness Center', 'Wine Shop', 'Indie Movie Theater',
                'Chocolate Shop', 'Dessert Shop', 'Recreation Center', 
                'Plaza', 'Hotel', 'Luggage Store', 'Farmers Market', 'Gym',
                'Jewelry Store', 'Furniture / Home Store', 'Butcher', 
                'Bakery', 'Marijuana Dispensary', 'Ice Cream Shop',
                'Comic Shop', 'Bagel Shop', 'Spa', 'Liquor Store', 'Bike Shop',
                'Yoga Studio', 'Pedestrian Plaza', 'Candy Store',
                'Park', 'Bookstore', 'Candy Store',  'Jazz Club', 'Art Gallery', 
                 'Supermarket', 'Museum', 'Boutique', 'Plaza', 'Building', 'Bakery',
                 'Historic Site', 'Ice Cream Shop', ' Concert Hall', 'Pharmacy', 
                 'Market', 'Movie Theater', 'Performing Arts Venue', 'Music Venue',
                 'Theater', 'Art Museum', 'Cheese Shop', 'Opera House',
                 'Pedestrian Plaza', 'School', 'Gift Shop', 'Athletics & Sports',
                 'Shoe Repair', 'General Entertainment', 'Stationery Store',
                 'Toy / Game Store', 'Brewery', 'Hotel', 'Theater', 'Music Venue', 'Business Service',
                 'Donut Shop', 'Liquor Store', 'Beer Store',
                 'Lounge', 'Plaza', 'Health Food Store', 'Concert Hall', 
                 'Lingerie Store', 'Gym', 'Mobile Phone Shop',
                 'Chocolate Shop', 'Ice Cream Shop', 'Hostel', 'Convenience Store', 
                 'Park', 'Farmers Market', 'Cosmetics Shop', 'Piano Bar',
                 'Nightclub', 'Massage Studio', 'Comedy Club', 'Concert Hall']

nearby_venues = nearby_venues[~nearby_venues['categories'].isin(removal_list)]

nearby_venues['categories'].unique()
# Out:
# array(['Caribbean Restaurant', 'Event Space', 'College Basketball Court',
#        'Coffee Shop', 'Poke Place', 'Mexican Restaurant', 'Hookah Bar',
#        'Korean Restaurant', 'Vietnamese Restaurant', 'Deli / Bodega',
#        'Cuban Restaurant', 'Burger Joint', 'Indian Restaurant',
#        'Food Service', 'Falafel Restaurant', 'Fast Food Restaurant',
#        'Greek Restaurant', 'Café', 'Moving Target', 'Dive Bar',
#        'Mediterranean Restaurant', 'Pizza Place', 'Sandwich Place',
#        'Strip Club', 'Juice Bar', 'American Restaurant',
#        'Southern / Soul Food Restaurant', 'Smoothie Shop',
#        'Rental Car Location', 'Food Truck', 'History Museum',
#        'Intersection', 'Gas Station', 'Sporting Goods Shop',
#        'Golf Course', 'Paper / Office Supplies Store', 'Wine Bar',
#        'Salon / Barbershop', 'Italian Restaurant', 'Brazilian Restaurant',
#        'Cocktail Bar', 'Tapas Restaurant', 'Seafood Restaurant',
#        'Indonesian Restaurant', 'New American Restaurant',
#        'Chinese Restaurant', 'Print Shop', 'Scenic Lookout',
#        'Grocery Store', 'Peruvian Restaurant', 'Breakfast Spot',
#        'French Restaurant', 'Pet Service', 'Restaurant', 'Bistro',
#        'Latin American Restaurant', 'Train Station',
#        'Gluten-free Restaurant', 'Japanese Restaurant', 'Fish Market',
#        'Bank', 'Asian Restaurant', 'Salad Place',
#        'Residential Building (Apartment / Condo)', 'Shopping Mall',
#        'Spanish Restaurant', 'Bar', 'Hotel Bar', 'Thai Restaurant',
#        'Electronics Store', 'Steakhouse', 'Trail', 'Speakeasy',
#        'Beer Garden', 'Health & Beauty Service', 'Sports Bar',
#        'Flea Market', 'Tex-Mex Restaurant', 'Gastropub', 'Irish Pub',
#        'Pub', 'Hockey Arena', 'Hockey Field', 'Dog Run', 'Skate Park',
#        'Tea Room', 'College Cafeteria', 'Automotive Shop',
#        'Light Rail Station', 'Football Stadium', 'Home Service',
#        'Thrift / Vintage Store', 'Boat or Ferry', 'Bus Station'],
#       dtype=object)

# %% [markdown]
# ### -----------    Get all the 'Likes' from FourSquare API -----------------------------------------------------

# %%
# set up to pull the likes from the API based on venue ID

url_list = []
like_list = []
json_list = []

for i in list(nearby_venues.id):
    venue_url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(i, CLIENT_ID, CLIENT_SECRET, VERSION)
    url_list.append(venue_url)
for link in url_list:
    result = requests.get(link).json()
    likes = result['response']['likes']['count']
    like_list.append(likes)
print(like_list)


nearby_venues['likes'] = like_list
nearby_venues.head()
# Out:
# [19, 51, 32, 101, 24, 27, 146, 57, 107, 58, 16, 8, 89, 1, 17, 15, 0, 78, 18, 12, 64, 19, 56, 24, 14, 306, 5, 98, 24, 8, 33, 1, 40, 10, 16, 25, 21, 0, 12, 4, 10, 0, 15, 8, 0, 3, 0, 33, 37, 12, 33, 117, 48, 22, 96, 11, 64, 43, 187, 29, 16, 140, 20, 10, 732, 44, 846, 95, 9, 120, 11, 8, 107, 153, 103, 13, 18, 224, 7, 22, 30, 9, 22, 973, 108, 229, 13, 22, 35, 75, 228, 14, 79, 13, 71, 250, 22, 15, 549, 18, 107, 233, 15, 76, 233, 17, 154, 61, 16, 12, 37, 62, 84, 32, 13, 316, 82, 267, 763, 209, 361, 15, 93, 103, 62, 28, 26, 44, 105, 21, 8, 16, 10, 33, 12, 20, 63, 239, 20, 0, 8, 140, 3, 86, 591, 6, 48, 69, 107, 185, 32, 19, 1703, 15, 206, 13, 0, 23, 30, 19, 6, 14, 90, 15, 13, 0, 6, 0, 0, 2, 3, 0, 3, 4, 1, 1, 20, 0, 1, 1, 1, 0, 2, 2]
#                              name                categories        lat  \
# 1              Jamrock Restaurant      Caribbean Restaurant  33.751554
# 2  Georgia Railroad Freight Depot               Event Space  33.751479
# 3                GSU Sports Arena  College Basketball Court  33.751735
# 4               Ebrik Coffee Room               Coffee Shop  33.753897
# 6                  Fish Bowl Poké                Poke Place  33.755727
#
#          lng                        id     city  likes
# 1 -84.391356  4c40e04eaf052d7f16817c79  Atlanta     19
# 2 -84.388224  4bc89a630050b71339b6ba3b  Atlanta     51
# 3 -84.386328  4bcda54968f976b0ce846483  Atlanta     32
# 4 -84.388782  5303ba1a498e8936e10f0c4a  Atlanta    101
# 6 -84.389400  57d42371498ebd10aa19e10b  Atlanta     24

# %% [markdown]
# ### Raw Data Set

# %%
raw_dataset = nearby_venues
raw_dataset.head()
# Out:
#                              name                categories        lat  \
# 1              Jamrock Restaurant      Caribbean Restaurant  33.751554
# 2  Georgia Railroad Freight Depot               Event Space  33.751479
# 3                GSU Sports Arena  College Basketball Court  33.751735
# 4               Ebrik Coffee Room               Coffee Shop  33.753897
# 6                  Fish Bowl Poké                Poke Place  33.755727
#
#          lng                        id     city  likes
# 1 -84.391356  4c40e04eaf052d7f16817c79  Atlanta     19
# 2 -84.388224  4bc89a630050b71339b6ba3b  Atlanta     51
# 3 -84.386328  4bcda54968f976b0ce846483  Atlanta     32
# 4 -84.388782  5303ba1a498e8936e10f0c4a  Atlanta    101
# 6 -84.389400  57d42371498ebd10aa19e10b  Atlanta     24

# %% [markdown]
# ### Data Preparation

# %%
# inspecting the raw dataset shows that there may be too many different types of cuisines
raw_dataset['categories'].unique()

# %% [markdown]
# ##### Categorizing the restaurants

# %%
# we can group some cuisines together to make a better categorical variable

euro = ['French Restaurant', 'Scandinavian Restaurant', 'Souvlaki Shop', 
       'Mediterranean Restaurant', 'Italian Restaurant', 'Pizza Place']

latino = ['Mexican Restaurant', 'Latin American Restaurant', 
          'Brazilian Restaurant', 'Taco Place']

bar = ['Beer Bar', 'Cocktail Bar', 'Tiki Bar', 'Wine Bar', 'Hotel Bar',
       'Beer Garden', 'Speakeasy', 'Brewery', 'Pub', 'Bar', 'Gastropub',
       'Hookah Bar']

asian = ['Ramen Restaurant', 'Sushi Restaurant', 'Vietnamese Restaurant',
         'Thai Restaurant', 'Poke Place', 'Indian Restaurant', 
         'Japanese Curry Restaurant', 'Japanese Restaurant', 
         'Indonesian Restaurant', 'Udon Restaurant', 'Noodle House',
         'Falafel Restaurant', 'Filipino Restaurant', 'Turkish Restaurant',
         'Yoshoku Restaurant']

casual = ['Coffee Shop', 'Café', 'Sandwich Place', 'Food Truck',
          'Juice Bar', 'Frozen Yogurt Shop', 'Deli / Bodega', 'Dessert Shop',
          'Hot Dog Joint', 'Burger Joint', 'Breakfast Spot', 
          'Fondue Restaurant']

american = ['Southern / Soul Food Restaurant', 'Food & Drink Shop', 
            'Restaurant', 'American Restaurant', 'BBQ Joint', 
            'Theme Restaurant', 'New American Restaurant',
            'Vegetarian / Vegan Restaurant', 'Seafood Restaurant']

def conditions(s):
    if s['categories'] in euro:
        return 'euro'
    if s['categories'] in latino:
        return 'latino'
    if s['categories'] in asian:
        return 'asian'
    if s['categories'] in casual:
        return 'casual'
    if s['categories'] in american:
        return 'american'
    if s['categories'] in bar:
        return 'bar'


raw_dataset['categories_classified']=raw_dataset.apply(conditions, axis=1)
raw_dataset
# Out:
#                                                  name  \
# 1                                  Jamrock Restaurant
# 2                      Georgia Railroad Freight Depot
# 3                                    GSU Sports Arena
# 4                                   Ebrik Coffee Room
# 6                                      Fish Bowl Poké
# 7                          Willy's Mexicana Grill #22
# 8                       Anatolia Cafe & Hookah Lounge
# 9                                        Blossom Tree
# 10                         Dua Vietnamese Noodle Soup
# 12                                      Reuben's Deli
# 13                                   Buenos Dias Cafe
# 15                                       Weekday Cafe
# 16                                           NaanStop
# 17                                        Chick-fil-A
# 19                                  Taqueria on Broad
# 20                                           Ali Baba
# 23                                        Chick-fil-A
# 24                                  Nick's Food To Go
# 27                                         Café Lucia
# 28                                Atlanta Movie Tours
# 29                          Elliott Street Deli & Pub
# 30                                    Baraka Shawarma
# 31                                       Rosa's Pizza
# 32                                     Condesa Coffee
# 34                              Atlanta Streets Alive
# 35                                    No Mas! Cantina
# 36                               Roly Poly Sandwiches
# 38                                         Magic City
# 41                                    Get Fruity Cafe
# 43                                     Arden's Garden
# 44                                    Glenn's Kitchen
# 46                                 Jersey Mike's Subs
# 47                                      Old Lady Gang
# 48                                       Jimmy John's
# 49                                   Sensational Subs
# 50                       Bada Bings Sports Food & Fun
# 51                                      Smoothie King
# 52                                         Enterprise
# 53                                    Good Food Truck
# 54                              Enterprise Rent-A-Car
# 56                                    The Apex Museum
# 57                              Enterprise Rent-A-Car
# 60                         I-20/I-75/I-85 Interchange
# 61                                                 BP
# 63                                  Unique Jazzy Body
# 65                                East Lake Golf Club
# 66        Fed Ex Office Georgia World Congress Center
# 0                                        Le Chat Noir
# 1                             Churchill's Barber Shop
# 2                                        Cane Á Sucre
# 4                                     Vero restaurant
# 6                                        Steak Brasil
# 7                                          Pawnbroker
# 8                                 Meraki Greek Bistro
# 10                                        NIU Kitchen
# 12            PEZ | Cocina de Mariscos Estilo Tijuana
# 14                                    Soya E Pomodoro
# 15                                          Bali Cafe
# 16                                    Fratelli Milano
# 17                                         PB station
# 18                               First Hong Kong Cafe
# 19                           Eternity Coffee Roasters
# 20                                     Miami Printing
# 21                                          Sky Lobby
# 22                                 Whole Foods Market
# 25                                       Jar and Fork
# 26                                        CVI.CHE 105
# 27                                Camila's Restaurant
# 28                                       The Egg Spot
# 29                                      Cafe Bastille
# 31                                    Animal Crackers
# 32                                    Chicken Kitchen
# 33                              Sparky's Roadside BBQ
# 36                                    Pollos y Jarras
# 37                                          La Granja
# 38                                         The Bistro
# 39                                         Boulud Sud
# 41                                 The Capital Grille
# 43                                      Atlantis Cafe
# 44                  elcielo By Juan Manuel Barrientos
# 45                                   Brightline Miami
# 46                                    Manna Life Food
# 47                                 Black Market Miami
# 48                                               Zuma
# 49                                    The Wharf Miami
# 50                                          Starbucks
# 52                                         Chase Bank
# 53                                         Station 28
# 54                                            Novikov
# 55                                         Ten Fruits
# 56                                            Area 31
# 57                                          Salad Box
# 59                                          One Miami
# 61                                             SUBWAY
# 62                                      Icon Brickell
# 63                               The River Oyster Bar
# 65                                        D'Oro Caffe
# 66                                           Farfalle
# 68                               Brickell City Centre
# 69                         Good Humor Ice Cream Truck
# 72                                    Casa Tua Cucina
# 74                                  Cipriani Downtown
# 75                                 Lost Boy Dry Goods
# 76                                 Iberico Pata Negra
# 78                                              Sugar
# 79                               Epic Hotel- Pool Bar
# 81                               Toro Toro Restaurant
# 82                                   Juan Valdez Café
# 83                            Manolo & Rene Cafeteria
# 84                   Intercontinental Hotel Lobby Bar
# 85                                     Luke's Lobster
# 88                                            Bonding
# 89                         Apple Brickell City Centre
# 90                                        Bon Fromage
# 93              Fleming’s Prime Steakhouse & Wine Bar
# 94                                        Il Gabbiano
# 96                         Brickell Key Jogging Trail
# 97                                          Truluck's
# 98                              Bubba Gump Shrimp Co.
# 0                               Eddie and Sam's Pizza
# 1                                     Tampa Riverwalk
# 2                                             SoFresh
# 3                                      Bamboozle Cafe
# 4                        First Watch - Downtown Tampa
# 6                Bavaro's Pizza Napoletana & Pastaria
# 7                                           Gin Joint
# 8                                 Tampa Pizza Company
# 81  514e0ad9e4b05b1019f2b3d6    Tampa      3                  None
# 82  4c34a65d3896e21ecadeeb90    Tampa      4              american
# 83  52606938498ec4928d8809f5    Tampa      1                  None
# 84  4bbe3b329474c9b6af4ad9b6    Tampa      1                  None
# 85  4b4ce83ef964a520bfc326e3    Tampa     20                  None
# 86  4f05efe4e5facc333e9693e1    Tampa      0                  None
# 87  4cbb998a4352a1cdc4dc99f5    Tampa      1                  None
# 88  58e1712d076be155f29cb718    Tampa      1              american
# 89  4dcc2b4752b19dd12dcbcfc6    Tampa      1                  None
# 90  539b7079498e07c13465a029    Tampa      0                  None
# 91  52a3869e11d29a4a41f4d511    Tampa      2                casual
# 92  58651bc69526bc197116d6b6    Tampa      2                  None

# %% [markdown]
# ###### Classifying the likes

# %%
# classify the likes into different ranking levels
# lets first see where to bin the data
# we can try different ways of binning the data, I find it yields substantially different results



print(np.percentile(raw_dataset['likes'], 33))
print(np.percentile(raw_dataset['likes'], 66))


# print(np.percentile(raw_dataset['likes'], 50))
# Out:
# 14.0
# 50.34

# %%
def rankings(s):
    if s['likes']<=14:
        return 1
    if s['likes']<=50.34:
        return 2
    if s['likes']>50.34:
        return 3
    
    

raw_dataset['ranking']=raw_dataset.apply(rankings, axis=1)
raw_dataset
# Out:
#                                                  name  \
# 1                                  Jamrock Restaurant
# 2                      Georgia Railroad Freight Depot
# 3                                    GSU Sports Arena
# 4                                   Ebrik Coffee Room
# 6                                      Fish Bowl Poké
# 7                          Willy's Mexicana Grill #22
# 8                       Anatolia Cafe & Hookah Lounge
# 9                                        Blossom Tree
# 10                         Dua Vietnamese Noodle Soup
# 12                                      Reuben's Deli
# 13                                   Buenos Dias Cafe
# 15                                       Weekday Cafe
# 16                                           NaanStop
# 17                                        Chick-fil-A
# 19                                  Taqueria on Broad
# 20                                           Ali Baba
# 23                                        Chick-fil-A
# 24                                  Nick's Food To Go
# 27                                         Café Lucia
# 28                                Atlanta Movie Tours
# 29                          Elliott Street Deli & Pub
# 30                                    Baraka Shawarma
# 31                                       Rosa's Pizza
# 32                                     Condesa Coffee
# 34                              Atlanta Streets Alive
# 35                                    No Mas! Cantina
# 36                               Roly Poly Sandwiches
# 38                                         Magic City
# 41                                    Get Fruity Cafe
# 43                                     Arden's Garden
# 44                                    Glenn's Kitchen
# 46                                 Jersey Mike's Subs
# 47                                      Old Lady Gang
# 48                                       Jimmy John's
# 49                                   Sensational Subs
# 50                       Bada Bings Sports Food & Fun
# 51                                      Smoothie King
# 52                                         Enterprise
# 53                                    Good Food Truck
# 54                              Enterprise Rent-A-Car
# 56                                    The Apex Museum
# 57                              Enterprise Rent-A-Car
# 60                         I-20/I-75/I-85 Interchange
# 61                                                 BP
# 63                                  Unique Jazzy Body
# 65                                East Lake Golf Club
# 66        Fed Ex Office Georgia World Congress Center
# 0                                        Le Chat Noir
# 1                             Churchill's Barber Shop
# 2                                        Cane Á Sucre
# 4                                     Vero restaurant
# 6                                        Steak Brasil
# 7                                          Pawnbroker
# 8                                 Meraki Greek Bistro
# 10                                        NIU Kitchen
# 12            PEZ | Cocina de Mariscos Estilo Tijuana
# 14                                    Soya E Pomodoro
# 15                                          Bali Cafe
# 16                                    Fratelli Milano
# 17                                         PB station
# 18                               First Hong Kong Cafe
# 19                           Eternity Coffee Roasters
# 20                                     Miami Printing
# 21                                          Sky Lobby
# 22                                 Whole Foods Market
# 25                                       Jar and Fork
# 26                                        CVI.CHE 105
# 27                                Camila's Restaurant
# 28                                       The Egg Spot
# 29                                      Cafe Bastille
# 31                                    Animal Crackers
# 32                                    Chicken Kitchen
# 33                              Sparky's Roadside BBQ
# 36                                    Pollos y Jarras
# 37                                          La Granja
# 38                                         The Bistro
# 39                                         Boulud Sud
# 41                                 The Capital Grille
# 43                                      Atlantis Cafe
# 44                  elcielo By Juan Manuel Barrientos
# 45                                   Brightline Miami
# 46                                    Manna Life Food
# 47                                 Black Market Miami
# 48                                               Zuma
# 49                                    The Wharf Miami
# 50                                          Starbucks
# 52                                         Chase Bank
# 53                                         Station 28
# 54                                            Novikov
# 55                                         Ten Fruits
# 56                                            Area 31
# 57                                          Salad Box
# 59                                          One Miami
# 61                                             SUBWAY
# 62                                      Icon Brickell
# 63                               The River Oyster Bar
# 65                                        D'Oro Caffe
# 66                                           Farfalle
# 68                               Brickell City Centre
# 69                         Good Humor Ice Cream Truck
# 72                                    Casa Tua Cucina
# 74                                  Cipriani Downtown
# 75                                 Lost Boy Dry Goods
# 76                                 Iberico Pata Negra
# 78                                              Sugar
# 79                               Epic Hotel- Pool Bar
# 81                               Toro Toro Restaurant
# 82                                   Juan Valdez Café
# 83                            Manolo & Rene Cafeteria
# 84                   Intercontinental Hotel Lobby Bar
# 85                                     Luke's Lobster
# 88                                            Bonding
# 89                         Apple Brickell City Centre
# 90                                        Bon Fromage
# 93              Fleming’s Prime Steakhouse & Wine Bar
# 94                                        Il Gabbiano
# 96                         Brickell Key Jogging Trail
# 97                                          Truluck's
# 98                              Bubba Gump Shrimp Co.
# 0                               Eddie and Sam's Pizza
# 1                                     Tampa Riverwalk
# 2                                             SoFresh
# 3                                      Bamboozle Cafe
# 4                        First Watch - Downtown Tampa
# 6                Bavaro's Pizza Napoletana & Pastaria
# 7                                           Gin Joint
# 8                                 Tampa Pizza Company
# 9                                           Starbucks
# 11                               Yeoman's Cask & Lion
# 13                            The Anchor Bar Downtown
# 15                 European Wax Center Downtown Tampa
# 16                                          HOTEL BAR
# 17                                     Inside The Box
# 19                      Paninoteca Mediterranean Cafe
# 20                                        Fusion bowl
# 21                                     Caffeine Tampa
# 22                      Kahwa Espresso Bar at Element
# 23                                          Hattricks
# 24                              Tampa Downtown Market
# 25                                      Tijuana Flats
# 26                              Pokeys Rock and Rolls
# 27                             Anise Global Gastrobar
# 28                                  Buddy Brew Coffee
# 29                                  TAPS Bar & Lounge
# 32                                    Oxford Exchange
# 37              Four Green Fields @ Curtis Hixon Park
# 38                                  Buddy Brew Coffee
# 41                                      Mise en Place
# 42                                  Four Green Fields
# 43                                             Publix
# 44                                   Premium Entrance
# 74                              Cocktail Bar  27.947281 -82.452420
# 76                       Rental Car Location  27.952200 -82.451600
# 77                           Automotive Shop  27.949846 -82.452575
# 78                      Fast Food Restaurant  27.956108 -82.456190
# 79                        Light Rail Station  27.948914 -82.451853
# 80                         Electronics Store  27.953933 -82.460621
# 81                          Football Stadium  27.943028 -82.452639
# 82                       American Restaurant  27.942975 -82.452639
# 83                              Home Service  27.942871 -82.452646
# 84                    Thrift / Vintage Store  27.954763 -82.461094
# 85                             Train Station  27.952546 -82.450647
# 86                             Boat or Ferry  27.951739 -82.451101
# 87                                   Dog Run  27.940626 -82.455291
# 88                       American Restaurant  27.942795 -82.451750
# 89                               Bus Station  27.955506 -82.458692
# 90                               Bus Station  27.956052 -82.456873
# 91                                Food Truck  27.953474 -82.451207
# 92                             Boat or Ferry  27.939920 -82.454435
#
#                           id     city  likes categories_classified  ranking
# 1   4c40e04eaf052d7f16817c79  Atlanta     19                  None        2
# 2   4bc89a630050b71339b6ba3b  Atlanta     51                  None        3
# 3   4bcda54968f976b0ce846483  Atlanta     32                  None        2
# 4   5303ba1a498e8936e10f0c4a  Atlanta    101                casual        3
# 6   57d42371498ebd10aa19e10b  Atlanta     24                 asian        2
# 7   4edfbffb8231abf7c29f5092  Atlanta     27                latino        2
# 8   4b6315eaf964a520e8612ae3  Atlanta    146                   bar        3
# 9   4d920f119d0f721e6b692473  Atlanta     57                  None        3
# 10  4a92bba3f964a5207e1d20e3  Atlanta    107                 asian        3
# 12  4a89913bf964a5206d0820e3  Atlanta     58                casual        3
# 13  5137900ee4b02636ec369b28  Atlanta     16                  None        2
# 15  4a96a2aef964a5206e2620e3  Atlanta      8                casual        1
# 16  5022e0a08302914e79bbd79b  Atlanta     89                 asian        3
# 17  4e4e040abd4101d0d7a049e7  Atlanta      1                  None        1
# 19  55e1f5c9498ef945929c09ce  Atlanta     17                latino        2
# 20  4a96a5a1f964a520762620e3  Atlanta     15                 asian        2
# 23  573a5f6f498ebef70d77d306  Atlanta      0                  None        1
# 24  4abbf3d9f964a520a28520e3  Atlanta     78                  None        3
# 27  55c13535498e29ed85fd18b8  Atlanta     18                casual        2
# 28  4fef03a2e4b05dce3a2f5576  Atlanta     12                  None        1
# 29  49f2218cf964a520f3691fe3  Atlanta     64                  None        3
# 30  4f7c8a33e4b0abe223b28301  Atlanta     19                  euro        2
# 31  4a3d0774f964a520bda11fe3  Atlanta     56                  euro        3
# 32  5511ae97498e3dbab7202e97  Atlanta     24                casual        2
# 34  5071b594e4b09822b9495d91  Atlanta     14                  None        1
# 35  4a4564c1f964a52020a81fe3  Atlanta    306                latino        3
# 36  4a8d7de1f964a520cb0f20e3  Atlanta      5                casual        1
# 38  40e0b100f964a520dd061fe3  Atlanta     98                  None        3
# 41  4fa94636e4b02cc7405ee8d6  Atlanta     24                casual        2
# 43  5519caba498eb847ed6c7f7b  Atlanta      8                casual        1
# 44  4c76fa7b93faa093a17eeffb  Atlanta     33              american        2
# 46  56cccdf9498e7c490c97a364  Atlanta      1                casual        1
# 47  58d71061ecb67e3da5248c0f  Atlanta     40              american        2
# 48  4e70e1d4ae602b2e727b8094  Atlanta     10                casual        1
# 49  453db8eaf964a520203c1fe3  Atlanta     16                casual        2
# 50  5309564c498e0672e3a3e6ec  Atlanta     25                  None        2
# 51  4a6a153cf964a52094cc1fe3  Atlanta     21                  None        2
# 52  4ed646f10aaf6cc6c9833dad  Atlanta      0                  None        1
# 53  4c9cd2ed46978cfa3097917f  Atlanta     12                casual        1
# 54  4f6e3317e4b0e428430d2260  Atlanta      4                  None        1
# 56  4c2b5e989a559c74b6340de2  Atlanta     10                  None        1
# 57  4b54ae67f964a520c4c627e3  Atlanta      0                  None        1
# 60  4b6b7984f964a5201f0b2ce3  Atlanta     15                  None        2
# 61  4b2d2ca7f964a52032d024e3  Atlanta      8                  None        1
# 63  50e87e6929a64705ef6ad945  Atlanta      0                  None        1
# 65  505dd9a1e4b00e0d6e096efb  Atlanta      3                  None        1
# 66  4fc8cdd8e4b0681a47e579fa  Atlanta      0                  None        1
# 0   527ac973498e765bb78dc03f    Miami     33                   bar        2
# 1   4b69c666f964a52076b32be3    Miami     37                  None        2
# 2   526aa03a11d295569e76aaee    Miami     12                casual        1
# 4   52ab7e27498ed214345fec49    Miami     33                  euro        2
# 6   514b7bb8e4b0476ac82afd55    Miami    117                latino        3
# 7   57047385498e0bf50c062a15    Miami     48                   bar        2
# 8   57d2f255498e3aca32c8b021    Miami     22                  None        2
# 10  5386767c498ebeec0447eee1    Miami     96                  None        3
# 12  5b1fc87e35f983002c332ea6    Miami     11              american        1
# 14  4bbcbf3ba0a0c9b6fdb91a0f    Miami     64                  euro        3
# 15  4ac6a54cf964a52099b520e3    Miami     43                 asian        2
# 16  4b5748caf964a5203a2f28e3    Miami    187                  euro        3
# 17  5706f4d0cd10b753577e7194    Miami     29              american        2
# 18  4e3057b614953296330daf50    Miami     16                  None        2
# 19  4dee656345dd3aa41d7c07a9    Miami    140                casual        3
# 20  4f5bf4f800399e87478714bf    Miami     20                  None        2
# 21  4d28fec98292236a8fd91ebb    Miami     10                  None        1
# 22  515989a3e4b03ece5bbf55a0    Miami    732                  None        3
# 25  5575db76498e3c32c82dc993    Miami     44              american        2
# 26  4aec9567f964a52009c921e3    Miami    846                  None        3
# 27  4b9fb9aaf964a520c33837e3    Miami     95                latino        3
# 28  5cb7308164c8e1002c9ca2c5    Miami      9                casual        1
# 29  4b571346f964a520672528e3    Miami    120                  euro        3
# 31  4cb7945d9552b60cce0ac68b    Miami     11                  None        1
# 32  58addad64bc2f1127b6a002b    Miami      8              american        1
# 33  4be2f57c21d5a59326c41711    Miami    107              american        3
# 36  4f3d12e4e4b00d955f03f3ed    Miami    153                  None        3
# 37  4e36d74752b17fb1c6162ecf    Miami    103                  None        3
# 38  4da78a6dfa8c4175d0a49f6c    Miami     13                  None        1
# 39  5a8910633abcaf25dc9fa3d1    Miami     18                  euro        2
# 41  4a91e72bf964a5204c1c20e3    Miami    224              american        3
# 43  4c406e73d7fad13a2aec05da    Miami      7                casual        1
# 8   54bc076c498e2e855ccbe9b8    Tampa     26                  euro        2
# 9   50f0c1f6e4b070fffd061a0f    Tampa     44                casual        2
# 11  5573b477498ebb62a29387c4    Tampa    105                   bar        3
# 13  53fb9ef8498e1c681f637321    Tampa     21                   bar        2
# 15  539f3c48498e51117da5a24a    Tampa      8                  None        1
# 16  582e482d0b5656378a7d9ce6    Tampa     16              american        2
# 17  4f184f72e4b0094a03ea11c8    Tampa     10                  None        1
# 19  4b6f24eff964a5200ee02ce3    Tampa     33                  euro        2
# 20  54c2a667498e1491aa29a771    Tampa     12                  None        1
# 21  572b9734cd10afb6e41e18fb    Tampa     20                casual        2
# 22  4f90194ce4b07ffef0b1fd05    Tampa     63                casual        3
# 23  4b1d1cc0f964a520ef0b24e3    Tampa    239                  None        3
# 24  4bacda66f964a52023123be3    Tampa     20                  None        2
# 25  531df0aa498e00b8113c1da9    Tampa      0                  None        1
# 26  574b00cd38faad9e98aec741    Tampa      8                  None        1
# 27  51366c67e4b0c8f0cf227c67    Tampa    140                   bar        3
# 28  5c6dbc6983e380002bfaf9bb    Tampa      3                casual        1
# 29  4b0586c2f964a520016d22e3    Tampa     86                   bar        3
# 32  506362eee4b05ef2f2a36516    Tampa    591              american        3
# 37  5a6bd06cf193c029b13b9b67    Tampa      6                  None        1
# 38  511443dae4b054e531a021b0    Tampa     48                casual        2
# 41  4b736d09f964a520dfad2de3    Tampa     69              american        3
# 42  4b0586c1f964a520b56c22e3    Tampa    107                   bar        3
# 43  4b53b2dff964a5204aa827e3    Tampa    185                  None        3
# 44  54306424498e6631c107e652    Tampa     32                  None        2
# 45  511aca35e4b0c961a7322fb2    Tampa     19                  None        2
# 46  4b155032f964a52017b023e3    Tampa   1703                  None        3
# 48  5570dbd7498efff835721ec9    Tampa     15                  euro        2
# 51  4b94fc87f964a520848a34e3    Tampa    206                   bar        3
# 52  4df3daf0b0fb807158c3f297    Tampa     13                  None        1
# 53  4cf7e300c020b60cfcdb2775    Tampa      0                  None        1
# 55  4da1185e0f578cfaa7d78418    Tampa     23                  None        2
# 56  4ae1cd6bf964a520888721e3    Tampa     30              american        2
# 57  4ea0c7de8231546b557f196e    Tampa     19                  None        2
# 58  5668c804498e6205bac8b554    Tampa      6                  None        1
# 59  4bf9aca48d30d13a90a20218    Tampa     14                  None        1
# 63  54fb7ce2498ed745c1770552    Tampa     90                  None        3
# 64  5139001ae4b019e1c8714d2d    Tampa     15                  None        2
# 69  55f0a920498e7ae2837fc684    Tampa     13                casual        1
# 71  4edfa0ab2c5b1dfcbac030b3    Tampa      0                  None        1
# 74  4b0586c2f964a520de6c22e3    Tampa      6                   bar        1
# 76  50ec931a5d24ad73a5197eb5    Tampa      0                  None        1
# 77  578d276f498ed96114d454c0    Tampa      0                  None        1
# 78  5b0596e00d2be7002cb2eed7    Tampa      2                  None        1
# 79  4f136049e4b0958ec33854a2    Tampa      3                  None        1
# 80  4b86e124f964a5208da331e3    Tampa      0                  None        1
# 81  514e0ad9e4b05b1019f2b3d6    Tampa      3                  None        1
# 82  4c34a65d3896e21ecadeeb90    Tampa      4              american        1
# 83  52606938498ec4928d8809f5    Tampa      1                  None        1
# 84  4bbe3b329474c9b6af4ad9b6    Tampa      1                  None        1
# 85  4b4ce83ef964a520bfc326e3    Tampa     20                  None        2
# 86  4f05efe4e5facc333e9693e1    Tampa      0                  None        1
# 87  4cbb998a4352a1cdc4dc99f5    Tampa      1                  None        1
# 88  58e1712d076be155f29cb718    Tampa      1              american        1
# 89  4dcc2b4752b19dd12dcbcfc6    Tampa      1                  None        1
# 90  539b7079498e07c13465a029    Tampa      0                  None        1
# 91  52a3869e11d29a4a41f4d511    Tampa      2                casual        1
# 92  58651bc69526bc197116d6b6    Tampa      2                  None        1

# %%
# create dummies for linear regression modelling

# one hot encoding
reg_dataset = pd.get_dummies(raw_dataset[['categories_classified', 
                                          'city',]], 
                               prefix="", 
                               prefix_sep="")

# add name, ranking, and likes columns back to dataframe
reg_dataset['ranking'] = raw_dataset['ranking']
reg_dataset['likes'] = raw_dataset['likes']
reg_dataset['name'] = raw_dataset['name']

# move name column to the first column
reg_columns = [reg_dataset.columns[-1]] + list(reg_dataset.columns[:-1])
reg_dataset = reg_dataset[reg_columns]


reg_dataset.head()
# Out:
#                              name  american  asian  bar  casual  euro  latino  \
# 1              Jamrock Restaurant         0      0    0       0     0       0
# 2  Georgia Railroad Freight Depot         0      0    0       0     0       0
# 3                GSU Sports Arena         0      0    0       0     0       0
# 4               Ebrik Coffee Room         0      0    0       1     0       0
# 6                  Fish Bowl Poké         0      1    0       0     0       0
#
#    Atlanta  Miami  Tampa  ranking  likes
# 1        1      0      0        2     19
# 2        1      0      0        3     51
# 3        1      0      0        2     32
# 4        1      0      0        3    101
# 6        1      0      0        2     24

# %% [markdown]
# ### Linear Regression

# %%
# Multiple Linear Regression

msk = np.random.rand(len(reg_dataset)) < 0.8
train = reg_dataset[msk]
test = reg_dataset[~msk]

regr = linear_model.LinearRegression()
x = np.asanyarray(train[['american', 'asian', 'bar', 'casual',
                         'euro', 'latino', 'Atlanta', 
                         'Miami', 'Tampa']])
y = np.asanyarray(train[['likes']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[ -3.78988775 161.51490742  -5.85643628 -29.70209138 -14.83767144
#    22.63959249 -33.39053714  51.32121335 -17.93067621]]

# %%
# Multiple Linear Regression Prediction Capabilities

y_hat= regr.predict(test[['american', 'asian', 'bar', 'casual',
                         'euro', 'latino', 'Atlanta', 
                         'Miami', 'Tampa']])
x = np.asanyarray(test[['american', 'asian', 'bar', 'casual',
                         'euro', 'latino', 'Atlanta', 
                         'Miami', 'Tampa']])
y = np.asanyarray(test[['likes']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 109477.29
# Variance score: -0.07

# %%
# Multinomial Ordinal Logistic Regression

x_train = np.asanyarray(train[['american', 'asian', 'bar', 'casual',
                         'euro', 'latino', 'Atlanta', 
                         'Miami', 'Tampa']])
y_train = np.asanyarray(train['ranking'])

x_test = np.asanyarray(test[['american', 'asian', 'bar', 'casual',
                         'euro', 'latino', 'Atlanta', 
                         'Miami', 'Tampa']])
y_test = np.asanyarray(test['ranking'])


# LR = LogisticRegression(C=0.01, solver='liblinear').fit(x_train, y_train)
# LR

mul_ordinal = linear_model.LogisticRegression(multi_class='multinomial',
                                              solver='newton-cg',
                                              fit_intercept=True).fit(x_train,
                                                                      y_train)

mul_ordinal

coef = mul_ordinal.coef_[0]
print (coef)
# Out:
# [-0.5063774  -0.84236469 -0.70026549  0.0140772  -1.26199144 -0.83213579
#  -0.01079135 -0.33035077  0.34114624]

# %%
# Multinomial Ordinal Logistic Regression Prediction Capabilities

yhat = mul_ordinal.predict(x_test)
yhat

yhat_prob = mul_ordinal.predict_proba(x_test)
yhat_prob


jaccard_similarity_score(y_test, yhat)
# Out:
# 0.5588235294117647

# %%
log_loss(y_test, yhat_prob)
# Out:
# 1.0345057641524518

# %%
# Exploration of Coefficient Magnitudes of Full Dataset

x_all = np.asanyarray(reg_dataset[['american', 'asian', 'bar', 'casual',
                                   'euro', 'latino', 'Atlanta', 
                                   'Miami', 'Tampa']])
y_all = np.asanyarray(reg_dataset['ranking'])



LR = linear_model.LogisticRegression(multi_class='multinomial',
                                            solver='newton-cg',
                                            fit_intercept=True).fit(x_all,
                                                                    y_all)

LR

coef = LR.coef_[0]
print (coef)
# Out:
# [-0.62835187 -1.03805127 -0.88497594  0.01218413 -1.37910189 -0.86605282
#   0.06119138 -0.38561662  0.32442673]

# %%
print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.85      0.76        13
#            2       0.50      0.27      0.35        11
#            3       0.42      0.50      0.45        10
#
#    micro avg       0.56      0.56      0.56        34
#    macro avg       0.53      0.54      0.52        34
# weighted avg       0.55      0.56      0.54        34
